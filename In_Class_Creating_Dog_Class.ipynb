# %% [markdown]
# <a href="https://colab.research.google.com/github/jeandavidsonjacques00-jpg/Jean-Davidson-Jacques/blob/main/In_Class_Creating_Dog_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Understanding Classes, Objects, and Encapsulation (Part 2):
#
# **Dog class:**
# - Definition: Every dog object that is created will have the following attributes:
#   - Name
#   - Age
#   - Breed
#   - Shot status (whether the dog is up to date on its vaccinations)
#
# Next, we will create a Java program that defines this `Dog` class and creates instances (objects) of the `Dog` class. In this example, we will create 3 different dogs (i.e., 3 different instances of the `Dog` class).
#
# 1. **1st Dog:**
#   - Ginger
#   - 6
#   - Akita
#   - Up to date
#
# 2. **2nd dog:**
#   - Bowser
#   - 2
#   - Retriever
#   - Up to date
#
# 3. **3rd dog:**
#   - Roxy
#   - 1
#   - Beagle
#   - Up to date

# %% [markdown]
# **Write Java Program:**

# %%
# Out:
# Writing Dogs.java

# %% [markdown]
# **Compile:**

# %% [markdown]
# **Run:**

# %%
# Out:
# Name: Ginger
# Age: 6
# Breed: Akita
# Shot Status: true
#
# Name: Bowser
# Age: 2
# Breed: Retriever
# Shot Status: true
#
# Name: Roxy
# Age: 1
# Breed: Beagle
# Shot Status: true
#
# Name: Rex
# Age: 4
# Breed: German Shepherd
# Shot Status: true
#
# Rex is guarding the house!
#
# Name: Max
# Age: 5
# Breed: Doberman
# Shot Status: true
#
# Max is being lazy and is NOT guarding the house.

# %% [markdown]
# ## This is the First Java Application:

# %%
# Out:
# Writing First.java

# %%
# Out:
# First Java application

# %% [markdown]
# ## Checking for different Languages in CoLab

# %%
## Checking for Java:
# !java -version
# Out:
# openjdk version "11.0.24" 2024-07-16
# OpenJDK Runtime Environment (build 11.0.24+8-post-Ubuntu-1ubuntu322.04)
# OpenJDK 64-Bit Server VM (build 11.0.24+8-post-Ubuntu-1ubuntu322.04, mixed mode, sharing)

# %%
## Checking for Python:
# !python --version

# %%
## Checking for R:
# !R --version

# %%
## Checking for C:
# !gcc --version

# %%
## Checking for C++:
# !g++ --version

# %%
## Checking for Bash:
# !bash --version

# %%
## Checking for JavaScript:
# !node --version
