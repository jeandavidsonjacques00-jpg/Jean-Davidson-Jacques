# %% [markdown]
# <a href="https://colab.research.google.com/github/jeandavidsonjacques00-jpg/Jean-Davidson-Jacques/blob/main/JavaProjectDetails.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Online Shopping System Project (Java)
#
# This project will help you practice the concepts you've learned in Chapters 1-14 of Java. By the end of this project, you will have created a basic **Online Shopping System** that simulates an e-commerce experience like shopping at Target.
#
# ### Instructions
# - You will be creating multiple classes that work together to simulate an online shopping experience.
# - The focus of this project is to help you practice **Object-Oriented Programming (OOP)** concepts, exception handling, nested classes, and user interaction.
# - **Optional:** If you'd like to explore using a GUI for your project (`JOptionPane`), feel free to do so. However, GUI components **cannot be run in Colab**. Therefore, you would need to use an IDE like Eclipse or IntelliJ on your local machine.
# - For this Colab-based project, focus on **console-based input and output**.
#
# ### Project Overview
# Your system will include the following classes and functionalities:
#
# #### 1. **Product Class**
#    - Attributes: `productName`, `price`, `category`, `quantityInStock`.
#    - Create getter and setter methods for each attribute.
#    - Add a method to display product details.
#    - Create subclasses for different product categories named `Category` (`Electronics`, `Clothing`) using inheritance.
#    - `checkStock()`: Checks if the product is in stock. Returns `true` if `quantityInStock` is greater than 0; otherwise, returns `false`.
#    - `updateStock(int quantity)`: Subtracts the specified quantity from `quantityInStock` when a purchase is made.
#
#
# #### 2. **LoginInformation Class**
#    - Attributes: `userName`, `password`, `debitCardNumber`, `debitCardZipCode`.
#    - Add a method to validate login credentials.
#    - Add a method to retrieve user information (name, debit card details).
#
# #### 3. **Cart Class**
#    - Manages a list of `Product` objects.
#    - Methods to:
#      - Before adding products to the cart, call the `checkStock()` method of the `Product` class. Only add the product if it is in stock.
#      - Add products to the cart.
#      - Remove products from the cart.
#      - Display all products in the cart.
#      - Clear the cart.
#      - Implement a `getTotalProductCount()` method to return the total quantity of each product in the cart, which will be used to update the stock during the checkout process.
#
#
# #### 4. **Payment Class**
#    - Attributes: `totalAmount`, `paymentStatus`.
#    - **Nested Class: DebitCardValidator**
#      - Checks if the debit card has enough balance to complete the purchase.
#      - Validates that the debit card's zip code matches the user's inputted address zip code.
#    - Methods:
#      - `acceptPayment()`: Takes the total cost from the `SaleComputation` class and checks if payment can be processed.
#
# #### 5. **Tax Class**
#    - Calculates the taxes based on a fixed tax rate.
#    - Methods to:
#      - Calculate tax for a given cart total.
#      - Return the total amount after tax.
#
# #### 6. **SaleComputation Class**
#    - Computes the total cost of items in the cart.
#    - Methods to:
#      - Calculate the total cost, including taxes (using the `Tax` class).
#      - Add a `verifyStockBeforeCheckout()` method that loops through all products in the cart and ensures they have enough quantity in stock to be purchased.
#      - Send the total cost to the `Payment` class.
#
# #### 7. **Checkout Class**
#    - Displays the total price to the user.
#    - Prompts the user if they still want to proceed with the purchase.
#    - Calls the `verifyStockBeforeCheckout()` method in the `SaleComputation` class to ensure products are available for purchase.
#    - Calls the `Payment` class to finalize the transaction.
#    - If the transaction is successful, call the `updateStock()` method for each product in the cart to subtract the purchased quantity from the inventory.
#    - Collects the address, zip code, and name of the user.
#    - Validates that the address zip code matches the debit card's zip code. If not, returns an error.
#
# #### 8. **Exception Handling**
#    - Implement custom exceptions such as `InsufficientFundsException`, `InvalidZipCodeException`, and `ProductNotFoundException`.
#    - Use `try-catch` blocks to handle errors during payment processing and checkout.
#
# #### 9. **Discount Class (Optional)**
#    - Implements discounts or promotional codes.
#    - Methods to:
#      - Apply percentage-based or fixed-amount discounts.
#      - Integrate the discount into the total cost computation.
#
# #### 10. **Receipt Generation Class**
#    - Generates a receipt displaying a breakdown of the products, taxes, discounts, and the total amount paid.
#
# #### 11. **Inventory Management**
#    - Create a class to manage product inventory.
#    - Methods to:
#      - Check product availability.
#      - Update product quantities after a successful purchase.
#
# #### 12. **Order History Class**
#    - Maintains a list of past purchases.
#    - Allows the user to view their previous orders.
#
# #### 13. **Shipping Options (Optional)**
#    - Introduce different shipping options (standard, express).
#    - Modify the total cost based on the selected shipping option.
#
# ### Submission
# - The final project is due on **May 3rd at 11:59 PM**.
# - Upload your completed Java files.
# - Make sure your project is modular, with each functionality encapsulated in its respective class.
# - Test your project thoroughly to ensure all scenarios are handled correctly.
#
# ### Tips
# - Keep your classes well-organized, using comments to describe the functionality of each method.
# - Break down the problem into smaller parts and tackle one class at a time.
# - Use meaningful names for variables and methods.
#
# Good luck, and have fun building your Online Shopping System!

# %%
#@title Rubric
import pandas as pd

# Creating the rubric for the project
rubric_data = {
    "Criteria": [
        "Product Class Implementation",
        "LoginInformation Class Implementation",
        "Cart Class Implementation",
        "Payment Class and Nested DebitCardValidator",
        "Tax Class Implementation",
        "SaleComputation Class Implementation",
        "Checkout Class Implementation",
        "Exception Handling",
        "Discount Class (Optional)",
        "Receipt Generation Class",
        "Inventory Management",
        "Order History Class",
        "Shipping Options (Optional)",
        "Code Quality and Comments",
        "Overall Functionality and Testing"
    ],
    "Points Possible": [
        10, 10, 10, 15, 5, 10, 15, 10, 0, 10, 10, 10, 0, 10, 15
    ],
    "Description": [
        "Proper implementation of attributes, methods, and subclasses. Includes stock checking and updating.",
        "Validates login credentials and handles user information appropriately.",
        "Manages products, verifies stock before adding, and handles total quantities.",
        "Processes payment, checks balance, and validates zip codes using nested class.",
        "Correctly calculates taxes based on the total cart cost.",
        "Calculates the total cost, verifies stock, and sends total to Payment class.",
        "Handles user checkout, validates payment, and updates stock.",
        "Implements custom exceptions and handles errors effectively.",
        "Implements discount functionality.",
        "Generates a receipt displaying all details of the purchase.",
        "Checks product availability, updates stock, and manages inventory correctly.",
        "Maintains a record of past purchases, allowing user to view order history.",
        "Provides shipping options that affect the total cost.",
        "Code is well-organized, uses meaningful variable names, and includes comments explaining functionality.",
        "Overall project runs smoothly, meets requirements, and is thoroughly tested."
    ]
}

# Creating a DataFrame for the rubric
rubric_df = pd.DataFrame(rubric_data)
styled_df = rubric_df.style.set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'left')]},
     {'selector': 'td', 'props': [('text-align', 'left')]}]
).hide(axis='index')

# Displaying the rubric in Colab without the index
from IPython.display import display
display(styled_df)

# Calculating and displaying the total possible points
total_points = rubric_df['Points Possible'].sum()
print(f"Total Points Possible: {total_points}")
# Out:
# <style type="text/css">
# #T_38179 th {
#   text-align: left;
# }
# #T_38179 td {
#   text-align: left;
# }
# </style>
# <table id="T_38179" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_38179_level0_col0" class="col_heading level0 col0" >Criteria</th>
#       <th id="T_38179_level0_col1" class="col_heading level0 col1" >Points Possible</th>
#       <th id="T_38179_level0_col2" class="col_heading level0 col2" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_38179_row0_col0" class="data row0 col0" >Product Class Implementation</td>
#       <td id="T_38179_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_38179_row0_col2" class="data row0 col2" >Proper implementation of attributes, methods, and subclasses. Includes stock checking and updating.</td>
#     </tr>
#     <tr>
#       <td id="T_38179_row1_col0" class="data row1 col0" >LoginInformation Class Implementation</td>
# ...

# %%
# %%writefile Product.java
# public class Product {
#     private String productName;
#     private double price;
#     private String category;
#     private int quantityInStock;
#
#     public Product(String productName, double price, String category, int quantityInStock) {
#         this.productName = productName;
#         this.price = price;
#         this.category = category;
#         this.quantityInStock = quantityInStock;
#     }
#
#     public String getProductName() { return productName; }
#     public double getPrice() { return price; }
#     public String getCategory() { return category; }
#     public int getQuantityInStock() { return quantityInStock; }
#
#     public void setPrice(double price) { this.price = price; }
#     public void setQuantityInStock(int quantityInStock) { this.quantityInStock = quantityInStock; }
#
#     public void displayProductDetails() {
#         System.out.println("Product: " + productName +
#                            ", Category: " + category +
#                            ", Price: $" + price +
#                            ", In stock: " + quantityInStock);
#     }
#
#     public boolean checkStock(int requestedQty) {
#         return quantityInStock >= requestedQty;
#     }
#
#     public void updateStock(int quantity) {
#         this.quantityInStock -= quantity;
#     }
# }
#
# class Electronics extends Product {
#     public Electronics(String name, double price, int quantityInStock) {
#         super(name, price, "Electronics", quantityInStock);
#     }
# }
#
# class Clothing extends Product {
#     public Clothing(String name, double price, int quantityInStock) {
#         super(name, price, "Clothing", quantityInStock);
#     }
# }
# Out:
# Writing Product.java

# %%
# %%writefile Main.java
# public class Main {
#
#     // Make this class static so main() can use it
#     static class LoginInformation {
#         private String username;
#         private String password;
#         private String cardNumber;
#         private String zipCode;
#
#         public LoginInformation(String username, String password, String cardNumber, String zipCode) {
#             this.username = username;
#             this.password = password;
#             this.cardNumber = cardNumber;
#             this.zipCode = zipCode;
#         }
#
#         public boolean validateLogin(String user, String pass) {
#             return this.username.equals(user) && this.password.equals(pass);
#         }
#     }
#
#     public static void main(String[] args) {
#         LoginInformation login = new LoginInformation(
#             "john123", "mypassword", "1234567890123456", "07001"
#         );
#
#         boolean success = login.validateLogin("john123", "mypassword");
#
#         if (success) {
#             System.out.println("Login successful!");
#         } else {
#             System.out.println("Invalid username or password.");
#         }
#     }
# }
# Out:
# Overwriting Main.java

# %%
# !javac Main.java

# %%
# !java Main
# Out:
# Login successful!

# %%
# %%writefile Cart.java
# import java.util.ArrayList;
# import java.util.List;
#
# public class Cart {
#     private List<CartItem> items = new ArrayList<>();
#
#     public void addItem(Product product, int quantity) {
#         items.add(new CartItem(product, quantity));
#     }
#
#     public List<CartItem> getItems() {
#         return items;
#     }
#
#     public double getTotal() {
#         double total = 0;
#         for (CartItem item : items) {
#             total += item.getSubtotal();
#         }
#         return total;
#     }
#
#     public void printReceipt() {
#         System.out.println("===== Cart Receipt =====");
#         for (CartItem item : items) {
#             System.out.println(item);
#         }
#         System.out.println("------------------------");
#         System.out.printf("Total: $%.2f%n", getTotal());
#     }
# }
# Out:
# Overwriting Cart.java

# %%
# %%writefile CartItem.java
# public class CartItem {
#     private Product product;
#     private int quantity;
#
#     public CartItem(Product product, int quantity) {
#         this.product = product;
#         this.quantity = quantity;
#     }
#
#     public Product getProduct() {
#         return product;
#     }
#
#     public int getQuantity() {
#         return quantity;
#     }
#
#     public double getSubtotal() {
#         return product.getPrice() * quantity;
#     }
#
#     @Override
#     public String toString() {
#         return quantity + "x " + product.getProductName() +
#                " = $" + String.format("%.2f", getSubtotal());
#     }
# }
# Out:
# Overwriting CartItem.java

# %%
# !javac *.java

# %%
# !java Main
# Out:
# Login successful!

# %%
# %%writefile InsufficientFundsException.java
# public class InsufficientFundsException extends Exception {
#     public InsufficientFundsException(String message) {
#         super(message);
#     }
# }
# Out:
# Overwriting InsufficientFundsException.java

# %%
# %%writefile InvalidZipCodeException.java
# public class InvalidZipCodeException extends Exception {
#     public InvalidZipCodeException(String message) {
#         super(message);
#     }
# }
# Out:
# Writing InvalidZipCodeException.java

# %%
# %%writefile ProductNotFoundException.java
# public class ProductNotFoundException extends Exception {
#     public ProductNotFoundException(String message) {
#         super(message);
#     }
# }
# Out:
# Overwriting ProductNotFoundException.java

# %%
# !javac *.java

# %%
# !java Main
# Out:
# Login successful!

# %%
# %%writefile Tax.java
# public class Tax {
#     private static final double TAX_RATE = 0.07; // 7%
#
#     public double calculateTax(double subtotal) {
#         return subtotal * TAX_RATE;
#     }
#
#     public double totalWithTax(double subtotal) {
#         return subtotal + calculateTax(subtotal);
#     }
# }
# Out:
# Overwriting Tax.java

# %%
# !javac Tax.java

# %%
# %%writefile Payment.java
# public class Payment {
#     private double totalAmount;
#     private boolean paymentStatus;
#
#     public Payment(double totalAmount) {
#         this.totalAmount = totalAmount;
#         this.paymentStatus = false;
#     }
#
#     public boolean isPaymentSuccessful() {
#         return paymentStatus;
#     }
#
#     public void acceptPayment(LoginInformation loginInfo, String addressZip, double availableBalance)
#             throws InsufficientFundsException, InvalidZipCodeException {
#
#         DebitCardValidator validator = new DebitCardValidator(loginInfo, addressZip, availableBalance);
#
#         if (!validator.validateZipCode()) {
#             throw new InvalidZipCodeException("Address zip code does not match debit card zip code.");
#         }
#
#         if (!validator.hasSufficientFunds(totalAmount)) {
#             throw new InsufficientFundsException("Insufficient funds for this purchase.");
#         }
#
#         paymentStatus = true;
#     }
#
#     public static class DebitCardValidator {
#         private LoginInformation loginInfo;
#         private String addressZip;
#         private double availableBalance;
#
#         public DebitCardValidator(LoginInformation loginInfo, String addressZip, double availableBalance) {
#             this.loginInfo = loginInfo;
#             this.addressZip = addressZip;
#             this.availableBalance = availableBalance;
#         }
#
#         public boolean validateZipCode() {
#             return loginInfo.getDebitCardZipCode().equals(addressZip);
#         }
#
#         public boolean hasSufficientFunds(double amount) {
#             return availableBalance >= amount;
#         }
#     }
# }
# Out:
# Overwriting Payment.java

# %%
# %%writefile LoginInformation.java
# public class LoginInformation {
#     private String username;
#     private String password;
#     private String debitCardZipCode;
#
#     public LoginInformation(String username, String password, String debitCardZipCode) {
#         this.username = username;
#         this.password = password;
#         this.debitCardZipCode = debitCardZipCode;
#     }
#
#     public String getDebitCardZipCode() {
#         return debitCardZipCode;
#     }
# }
# Out:
# Overwriting LoginInformation.java

# %%
# !javac Main.java

# %%
# !java Main
# Out:
# Login successful!

# %%
# %%writefile SaleComputation.java
# public class SaleComputation {
#     private Cart cart;
#     private Tax tax;
#
#     public SaleComputation(Cart cart) {
#         this.cart = cart;
#         this.tax = new Tax();
#     }
#
#     public double computeSubtotal() {
#         double subtotal = 0;
#         for (var item : cart.getItems()) {
#             subtotal += item.getProduct().getPrice() * item.getQuantity();
#         }
#         return subtotal;
#     }
#
#     public boolean verifyStockBeforeCheckout() {
#         for (var item : cart.getItems()) {
#             if (!item.getProduct().checkStock(item.getQuantity())) {
#                 System.out.println("Not enough stock for " + item.getProduct().getProductName());
#                 return false;
#             }
#         }
#         return true;
#     }
#
#     public double computeTotalWithTax() {
#         double subtotal = computeSubtotal();
#         return tax.totalWithTax(subtotal);
#     }
# }
# Out:
# Overwriting SaleComputation.java

# %%
# %%writefile Checkout.java
# import java.util.Scanner;
#
# public class Checkout {
#
#     public void processCheckout(Cart cart, LoginInformation loginInfo, double availableBalance) {
#         Scanner scanner = new Scanner(System.in);
#         SaleComputation sale = new SaleComputation(cart);
#
#         if (!sale.verifyStockBeforeCheckout()) {
#             System.out.println("Checkout failed due to stock issues.");
#             return;
#         }
#
#         double total = sale.computeTotalWithTax();
#         System.out.printf("Your total (with tax) is: $%.2f%n", total);
#
#         System.out.print("Do you want to proceed? (yes/no): ");
#         String choice = scanner.nextLine();
#         if (!choice.equalsIgnoreCase("yes")) {
#             System.out.println("Checkout cancelled.");
#             return;
#         }
#
#         System.out.print("Enter shipping address: ");
#         String address = scanner.nextLine();
#         System.out.print("Enter shipping zip code: ");
#         String addressZip = scanner.nextLine();
#
#         Payment payment = new Payment(total);
#         try {
#             payment.acceptPayment(loginInfo, addressZip, availableBalance);
#             if (payment.isPaymentSuccessful()) {
#
#                 // Update stock using getters
#                 for (var item : cart.getItems()) {
#                     item.getProduct().updateStock(item.getQuantity());
#                 }
#
#                 System.out.println("Payment successful. Order placed!");
#             }
#         } catch (InsufficientFundsException | InvalidZipCodeException e) {
#             System.out.println("Checkout error: " + e.getMessage());
#         }
#     }
# }
# Out:
# Overwriting Checkout.java

# %%
# !javac *.java

# %%
# !java Main
# Out:
# Login successful!

# %%
# %%writefile Discount.java
# public class Discount {
#     private double percentage;
#
#     public Discount(double percentage) {
#         this.percentage = percentage;
#     }
#
#     public double apply(double amount) {
#         return amount - (amount * (percentage / 100));
#     }
# }
# Out:
# Writing Discount.java

# %%
# %%writefile Receipt.java
# public class Receipt {
#     public static void printReceipt(String productName, int quantity, double price, double total, boolean paymentStatus) {
#         System.out.println("----- RECEIPT -----");
#         System.out.println("Product: " + productName);
#         System.out.println("Quantity: " + quantity);
#         System.out.println("Price Each: $" + price);
#         System.out.println("Total: $" + total);
#         System.out.println("Payment: " + (paymentStatus ? "Successful" : "Failed"));
#         System.out.println("-------------------");
#     }
# }
# Out:
# Writing Receipt.java

# %%
# %%writefile Inventory.java
# import java.util.HashMap;
#
# public class Inventory {
#     private HashMap<String, Integer> stock = new HashMap<>();
#
#     public Inventory() {
#         stock.put("Laptop", 5);
#         stock.put("Headphones", 10);
#         stock.put("Mouse", 8);
#     }
#
#     public boolean isAvailable(String product, int quantity) {
#         return stock.containsKey(product) && stock.get(product) >= quantity;
#     }
#
#     public void reduceStock(String product, int quantity) {
#         stock.put(product, stock.get(product) - quantity);
#     }
# }
# Out:
# Writing Inventory.java

# %%
# %%writefile OrderHistory.java
# import java.util.ArrayList;
#
# public class OrderHistory {
#     private ArrayList<String> history = new ArrayList<>();
#
#     public void addOrder(String orderDetails) {
#         history.add(orderDetails);
#     }
#
#     public void showHistory() {
#         System.out.println("----- ORDER HISTORY -----");
#         for (String order : history) {
#             System.out.println(order);
#         }
#     }
# }
# Out:
# Writing OrderHistory.java

# %%
# !javac *.java

# %%
# !java Main
# Out:
# Login successful!
