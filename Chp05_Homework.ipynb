# %% [markdown]
# <a href="https://colab.research.google.com/github/jeandavidsonjacques00-jpg/Jean-Davidson-Jacques/blob/main/Chp05_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework Assignment
#
# ## **BEFORE YOU GO THROUGH THESE PROBLEMS REMEMBER TO MAKE A COPY OF THIS FILE INTO YOUR DRIVE OR ELSE IT WILL NOT SAVE YOUR CHANGES**
#
# **Go through these 5 assignment questions and 2 LeetCode problems to complete your Chapter 5 Homework**
#
# P.S. For each of these, you can decide what to name your Java program, hence you can decide what the name of the class should be. Try to name the class appropriately with what you're trying to achieve. Also, remember that the naming convention for classes is that the first letter for each word should be capitalized.
#
# *Note: You don't need to use OOP style programming to solve these problems. You can do all of these problems within the same class, and within the main method*
#
# 1. Number Comparison
#   - Take three integers fromn the user (using `Scanner` class).
#   - Use if-else statements to find the largest number.
#   - Print the largest number inputted.
#
# 2. Product Price Checker
#   - You input the price of a product, using the `Scanner` class. Based on the price, apply the following discounts using **if-else statements**:
#     - `if` price is greater than **$500** apply a **10%** discount.
#     - `if` price is between **$100** and **$500** apply a **5%** discount.
#     - 'if' price is less than **$100** then no discount is applied.
#   - Then apply the discount.
#   - After applying the discount, display the `finalPrice`.
#
# 3. Grade Calculator (Switch Case)
#   - Write a program that assigns a letter grade (A, B, C, D, or F) to a student based on their score using a **switch-case**.
#     - Using the `Scanner` class, input a student's score *(from 0-100)*.
#     - Based on this score, assign the letter grade as follows:
#       - 90-100: A
#       - 80-89: B
#       - 70-79: C
#       - 60-69: D
#       - Below 60: F
#
# 4. Day of the Week (Switch Case)
#   - Write a program that takes a number between 1 and 7, and prints the corresponding day of the week using a **switch-case** (1 for Monday, 2 for Tuesday, etc...).
#     - Using the `Scanner` class, input a number between 1 and 7.
#     - Use the switch-case to print the day of the week if the user inputs 1 then return Monday, etc...
#     - If the user enters a number outside this range, print `"Invalid Input"`
#
# 5. Even or Odd Number Check(If-Else)
#   - Write a program that takes an integer input from the user and checks if it is even or odd using `if-else` satements.
#     - Using the `Scanner` class, input an integer.
#     - Use `if-else` statements to check whether a number is even or odd.
#     - Print whether the number is even or odd.
#
# **Leetcode Problems:**
#
# These problems won't count towards your grade, but I **HIGHLY** encourage you to at least try to solve them because they will only help you develop yourself into a better programmer.
#
# - [Fizz Buzz](https://leetcode.com/problems/fizz-buzz/description/)
# - [Number of 1 Bits](https://leetcode.com/problems/number-of-1-bits/description/)

# %% [markdown]
# ## Question 1:

# %%
# %%writefile NumberComparison.java
# import java.util.Scanner;
#
# public class NumberComparison {
#     public static void main(String[] args) {
#         Scanner input = new Scanner(System.in);
#
#         System.out.print("Enter first number: ");
#         int a = input.nextInt();
#
#         System.out.print("Enter second number: ");
#         int b = input.nextInt();
#
#         System.out.print("Enter third number: ");
#         int c = input.nextInt();
#
#         int largest = a;
#
#         if (b > largest) {
#             largest = b;
#         }
#         if (c > largest) {
#             largest = c;
#         }
#
#         System.out.println("The largest number is: " + largest);
#     }
# }
# Out:
# Writing NumberComparison.java

# %% [markdown]
# **REMEMBER TO COMPILE AND RUN**

# %%
# !javac NumberComparison.java

# %%
# !java NumberComparison
# Out:
# Enter first number: 10
# Enter second number: 5
# Enter third number: 4
# The largest number is: 10

# %% [markdown]
# ## Question 2:

# %%
# %%writefile ProductPriceChecker.java
# import java.util.Scanner;
#
# public class ProductPriceChecker {
#     public static void main(String[] args) {
#         Scanner input = new Scanner(System.in);
#
#         System.out.print("Enter product price: ");
#         double price = input.nextDouble();
#         double discount = 0;
#
#         if (price > 500) {
#             discount = 0.10;
#         } else if (price >= 100 && price <= 500) {
#             discount = 0.05;
#         } else {
#             discount = 0;
#         }
#
#         double finalPrice = price - (price * discount);
#         System.out.println("Final price after discount: $" + finalPrice);
#     }
# }
# Out:
# Writing ProductPriceChecker.java

# %% [markdown]
# **REMEMBER TO COMPILE AND RUN**

# %%
# !javac ProductPriceChecker.java

# %%
# !java ProductPriceChecker
# Out:
# Enter product price: 50
# Final price after discount: $50.0

# %% [markdown]
# ## Question 3:

# %%
# %%writefile GradeCalculator.java
# import java.util.Scanner;
#
# public class GradeCalculator {
#     public static void main(String[] args) {
#         Scanner input = new Scanner(System.in);
#
#         System.out.print("Enter score (0-100): ");
#         int score = input.nextInt();
#         char grade;
#
#         switch (score / 10) {
#             case 10:
#             case 9: grade = 'A'; break;
#             case 8: grade = 'B'; break;
#             case 7: grade = 'C'; break;
#             case 6: grade = 'D'; break;
#             default: grade = 'F';
#         }
#
#         System.out.println("Your grade is: " + grade);
#     }
# }
# Out:
# Writing GradeCalculator.java

# %% [markdown]
# **REMEMBER TO COMPILE AND RUN**

# %%
# !javac GradeCalculator.java

# %%
# !java GradeCalculator
# Out:
# Enter score (0-100): 95
# Your grade is: A

# %% [markdown]
# ## Question 4:

# %%
# %%writefile DayOfWeek.java
# import java.util.Scanner;
#
# public class DayOfWeek {
#     public static void main(String[] args) {
#         Scanner input = new Scanner(System.in);
#
#         System.out.print("Enter a number (1-7): ");
#         int day = input.nextInt();
#
#         switch (day) {
#             case 1: System.out.println("Monday"); break;
#             case 2: System.out.println("Tuesday"); break;
#             case 3: System.out.println("Wednesday"); break;
#             case 4: System.out.println("Thursday"); break;
#             case 5: System.out.println("Friday"); break;
#             case 6: System.out.println("Saturday"); break;
#             case 7: System.out.println("Sunday"); break;
#             default: System.out.println("Invalid Input");
#         }
#     }
# }
# Out:
# Writing DayOfWeek.java

# %% [markdown]
# **REMEMBER TO COMPILE AND RUN**

# %%
# !javac DayOfWeek.java

# %%
# !java DayOfWeek
# Out:
# Enter a number (1-7): 5
# Friday

# %% [markdown]
# ## Question 5:

# %%
# %%writefile EvenOrOdd.java
# import java.util.Scanner;
#
# public class EvenOrOdd {
#     public static void main(String[] args) {
#         Scanner input = new Scanner(System.in);
#
#         System.out.print("Enter a number: ");
#         int num = input.nextInt();
#
#         if (num % 2 == 0) {
#             System.out.println(num + " is even.");
#         } else {
#             System.out.println(num + " is odd.");
#         }
#     }
# }
# Out:
# Writing EvenOrOdd.java

# %% [markdown]
# **REMEMBER TO COMPILE AND RUN**

# %%
# !javac EvenOrOdd.java

# %%
# !java EvenOrOdd
# Out:
# Enter a number: 8
# 8 is even.

# %% [markdown]
# ## LeetCode Problems:
#
# Once you're done with the LeetCode problems, please paste them below to show you completed them:

# %%
# %%writefile FizzBuzz.java
# public class FizzBuzz {
#     public static void main(String[] args) {
#         for (int i = 1; i <= 100; i++) {
#             if (i % 3 == 0 && i % 5 == 0)
#                 System.out.println("FizzBuzz");
#             else if (i % 3 == 0)
#                 System.out.println("Fizz");
#             else if (i % 5 == 0)
#                 System.out.println("Buzz");
#             else
#                 System.out.println(i);
#         }
#     }
# }
# Out:
# Overwriting FizzBuzz.java

# %%
# !javac FizzBuzz.java

# %%
# !java FizzBuzz
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz
